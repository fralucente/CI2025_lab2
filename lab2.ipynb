# %%
import numpy as np
import random 
from icecream import ic

# %% [markdown]
# Hamiltonian circle with minimum cost

# %% [markdown]
# input=square diagonal simmetric matrix

# %%
def fitness(sol,dist):
    val=0
    for i in range(len(sol)-1):
        val+=dist[sol[i]][sol[i+1]]
    val+=dist[0][sol[-1]]
    return val

# %%
def swap_mutation(sol):
    i=random.randint(0,len(sol)-1)
    j=random.randint(0,len(sol)-1)
    sol[i],sol[j]=sol[j],sol[i]
    return sol
def inversion_mutation(sol):
    i=random.randint(0,len(sol)-1)
    j=random.randint(0,len(sol)-1)
    if i>j:
        i,j=j,i
    sol[i:j+1]=reversed(sol[i:j+1])
    return sol

# %%
def crossover(sol1,sol2):
    size=len(sol1)
    start=random.randint(0,size-1)
    end=random.randint(0,size-1)
    if start>end:
        start,end=end,start
    newsol=[-1]*size
    for i in range(start,end+1):
        newsol[i]=sol1[i]
    pos=(end+1)%size
    for i in range(size):
        idx=(end+1+i)%size
        if sol2[idx] not in newsol:
            newsol[pos]=sol2[idx]
            pos=(pos+1)%size
    return newsol

# %%
def tournament_selection(pop,dist,k):
    best=None
    for i in range(k):
        ind=random.randint(0,len(pop)-1)
        if best is None or fitness(pop[ind],dist)<fitness(best,dist):
            best=pop[ind]
    return best

# %%
def random_solution(n_cities):
    sol = list(range(n_cities))
    random.shuffle(sol)
    return sol

# %%
def init_population(pop_size, n_cities):
    return [random_solution(n_cities) for _ in range(pop_size)]

# %%
def find_solution(dist,popk=5, generations=500, mutation_rate=0.1, tournament_size=5):
    n_cities=dist.shape[0]
    pop_size=min(popk*n_cities,300)
    population=init_population(pop_size,n_cities)
    best_solution=None
    no_improvement=0
    for gen in range(generations):
        new_population=[best_solution[:]] if best_solution is not None else []
        for _ in range(pop_size):
            parent1=tournament_selection(population,dist,tournament_size)
            parent2=tournament_selection(population,dist,tournament_size)
            child=crossover(parent1,parent2)
            if random.random()<mutation_rate:
                if random.random()<0.5:
                    child=swap_mutation(child)
                else:
                    child=inversion_mutation(child)
            new_population.append(child)
        population=new_population
        current_best=min(population, key=lambda sol: fitness(sol, dist))
        if best_solution is None or fitness(current_best, dist)<fitness(best_solution, dist):
            best_solution=current_best
            no_improvement=0
            ic(f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}")
        else:
            no_improvement+=1
        if no_improvement>=50:
            break
    return best_solution

# %%
test=np.load("lab2/test_problem.npy")
solution=find_solution(test)
fitness_value=fitness(solution,test)
fitness_value
# Out:
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 0: Best fitness = 6059.96'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 1: Best fitness = 5241.669999999999'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 3: Best fitness = 4519.330000000001'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 5: Best fitness = 4399.240000000001'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 6: Best fitness = 4226.42'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 7: Best fitness = 4124.48'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 8: Best fitness = 4100.820000000001'
# ic| f"Generation {gen}: Best fitness = {fitness(best_solution, dist)}": 'Generation 9: Best fitness = 4060.23'
# ...
